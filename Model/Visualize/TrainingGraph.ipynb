# %%
# Training phase (epochs 1–30)
epochs_train = list(range(1, 31))

train_acc = [
    0.4187, 0.6558, 0.7379, 0.7975, 0.8128, 0.8378, 0.8473, 0.8582, 0.8720, 0.8808,
    0.8877, 0.8973, 0.8987, 0.9065, 0.9107, 0.9128, 0.9176, 0.9226, 0.9298, 0.9288,
    0.9342, 0.9363, 0.9368, 0.9443, 0.9406, 0.9439, 0.9439, 0.9498, 0.9485, 0.9481
]

val_acc = [
    0.6651, 0.7665, 0.8005, 0.8212, 0.8352, 0.8526, 0.8479, 0.8652, 0.8686, 0.8706,
    0.8853, 0.8906, 0.8879, 0.8999, 0.8979, 0.8833, 0.9039, 0.9139, 0.9119, 0.9146,
    0.9173, 0.9226, 0.9246, 0.9173, 0.9213, 0.9193, 0.9253, 0.9233, 0.9186, 0.9226
]

train_loss = [
    0.2278, 0.1587, 0.1289, 0.1083, 0.0995, 0.0896, 0.0840, 0.0767, 0.0714, 0.0675,
    0.0650, 0.0591, 0.0576, 0.0551, 0.0521, 0.0502, 0.0471, 0.0453, 0.0425, 0.0416,
    0.0398, 0.0396, 0.0378, 0.0343, 0.0360, 0.0340, 0.0343, 0.0323, 0.0317, 0.0322
]

val_loss = [
    0.1541, 0.1166, 0.0998, 0.0912, 0.0825, 0.0769, 0.0830, 0.0722, 0.0707, 0.0657,
    0.0609, 0.0603, 0.0571, 0.0556, 0.0561, 0.0653, 0.0562, 0.0493, 0.0517, 0.0516,
    0.0475, 0.0449, 0.0437, 0.0460, 0.0478, 0.0449, 0.0430, 0.0443, 0.0446, 0.0468
]

# %%
# Fine-tuning phase (epochs 1–10)
epochs_ft = list(range(1, 11))

ft_train_acc = [
    0.7833, 0.8845, 0.9105, 0.9344, 0.9503, 0.9578, 0.9626, 0.9684, 0.9709, 0.9790
]

ft_val_acc = [
    0.8846, 0.9139, 0.9273, 0.9453, 0.9533, 0.9626, 0.9666, 0.9640, 0.9693, 0.9740
]

ft_train_loss = [
    0.1310, 0.0640, 0.0486, 0.0397, 0.0305, 0.0267, 0.0230, 0.0211, 0.0175, 0.0137
]

ft_val_loss = [
    0.0618, 0.0487, 0.0413, 0.0309, 0.0281, 0.0242, 0.0215, 0.0198, 0.0174, 0.0163
]

# %%
from matplotlib import pyplot as plt
epochs = list(range(1, 31))

plt.figure(figsize=(12, 4))  # 👈 wider: 12 units width, 4 units height

# Accuracy
plt.subplot(1, 2, 1)
plt.plot(epochs, train_acc, label='Train Accuracy')
plt.plot(epochs, val_acc, label='Validation Accuracy')
plt.ylim(0, 1.2)
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy over Epochs')
plt.legend()

# Loss
plt.subplot(1, 2, 2)
plt.plot(epochs, train_loss, label='Train Loss')
plt.plot(epochs, val_loss, label='Validation Loss')
plt.ylim(0, 1.2)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss over Epochs')
plt.legend()

plt.tight_layout()
plt.show()

# %%
from matplotlib import pyplot as plt
epochs = list(range(1, 11))

# Accuracy
plt.subplot(1, 2, 1)
plt.plot(epochs, ft_train_acc, label='Train Accuracy')
plt.plot(epochs, ft_val_acc, label='Validation Accuracy')
plt.ylim(0, 1.2)
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy over Epochs')
plt.legend()

# Loss
plt.subplot(1, 2, 2)
plt.plot(epochs, ft_train_loss, label='Train Loss')
plt.plot(epochs, ft_val_loss, label='Validation Loss')
plt.ylim(0, 1.2)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss over Epochs')
plt.legend()

plt.tight_layout()
plt.show()
